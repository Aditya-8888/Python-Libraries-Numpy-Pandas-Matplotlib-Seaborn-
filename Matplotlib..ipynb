# %%
pip install matplotlib.pylot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pylot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pylot
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[50,60,55,70,65]
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4,5]
y=[50,60,55,70,65]
plt.figure(figsize=(5,3))
plt.plot(x,y)
plt.show()

# %%
a=[4,7,10,22,10]
b=[100,130,120,133,240]
plt.plot(a,b)
plt.show()

# %%
import numpy as np

# %%
# by using numpy
x=np.arange(1,100,10)
y=np.linspace(50,100,10)
plt.figure(figsize=(5,3))
plt.plot(x,y)
plt.show()

# %%
x=np.random.randint(0,20,50)
x
# Out:
# array([ 3,  3, 17,  9, 12, 17,  6, 18, 10, 11, 16, 18, 12,  2,  9, 12,  4,
#        11, 13,  1, 14,  6,  6,  5,  6, 18, 18, 14, 18,  9, 19,  6,  1,  3,
#        16,  5, 11,  5, 12,  7, 12, 14,  5, 14, 13,  9, 10, 15, 11,  8])

# %%
x=np.random.randint(50,100,5)
y=np.linspace(0,20,5)
plt.figure(figsize=(5,3))
plt.plot(x,y)
plt.show()

# %%
x=np.random.randint(0,20,20)
y=np.linspace(10,500,20)
plt.figure(figsize=(5,3))
plt.scatter(x,y)
plt.show()

# %%
x=np.random.randint(0,20,20)
y=np.linspace(10,500,20)
plt.figure(figsize=(5,3))
plt.scatter(x,y)
plt.title("Scatter plot")
plt.show()

# %%
x=np.random.randint(0,20,20)
y=np.linspace(10,500,20)
plt.figure(figsize=(5,3))
plt.scatter(x,y)
plt.title("Scatter plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3)) # change the graph size
plt.scatter(Subjects,Marks)
plt.title("Scatter plot-Student Report") # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3)) # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks) #  plot is use for line graph
plt.title("Scatter plot-Student Report") # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3)) # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="Orange") #color="Orange" which is used for to change the color
plt.title("Scatter plot-Student Report") # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3)) # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="Orange",marker="o")  # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report") # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# marker edge color = mec
#
#
# marker face color =mfc

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="Orange",marker="o",mec="red")                                         # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="Orange",marker="o",mec="red",mfc="blue")                                         # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="Orange",marker="*",mec="red",mfc="blue")                                         # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="Orange",marker="*",mec="red",mfc="blue",markersize=15)                                         # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="*",mec="black",mfc="pink",markersize=30)                                         # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(10,5))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="*",mec="black",mfc="red",markersize=100)                                         # marker="o" which is used for to change the marker
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="*",mec="black",mfc="red",markersize=30,linestyle="--")         
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="*",mec="black",mfc="red",markersize=30,linestyle="-.")         
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="*",mec="black",mfc="red",markersize=15,linestyle="-.",linewidth=2.5)         
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
x1=np.linspace(0,20,50)
y1=np.log(x1)
plt.figure(figsize=(5,3))
plt.plot(x1,y1)
plt.title("2D graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
# Out:
# C:\Users\hplap\AppData\Local\Temp\ipykernel_21140\3978132941.py:2: RuntimeWarning: divide by zero encountered in log
#   y1=np.log(x1)

# %%
x1=np.linspace(0,20,50)
y1=np.log(x1)
x2=np.linspace(0,20,20)
y2=np.exp(x2)
plt.figure(figsize=(5,3))
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.title("2D graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
# Out:
# C:\Users\hplap\AppData\Local\Temp\ipykernel_21140\1885341184.py:2: RuntimeWarning: divide by zero encountered in log
#   y1=np.log(x1)

# %%
x1=np.linspace(0,20,50)
y1=np.sin(x1)
x2=np.linspace(0,20,20)
y2=np.cos(x2)
plt.figure(figsize=(5,3))
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.title("2D graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x1=np.linspace(0,20,50)
y1=np.sin(x1)
x2=np.linspace(0,20,20)
y2=np.cos(x2)
plt.figure(figsize=(5,3))
plt.plot(x1,y1,label="Sin Curve")
plt.plot(x2,y2,label="Cos Curve")
plt.title("2D graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot("legend")
plt.show()

# %%
x1=np.linspace(0,20,50)
y1=np.sin(x1)
x2=np.linspace(0,20,20)
y2=np.cos(x2)
plt.figure(figsize=(5,3))
plt.plot(x1,y1,label="Sin Curve",color="red")
plt.plot(x2,y2,label="Cos Curve",color="black")
plt.title("2D graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot("legend")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.bar(Subjects,Marks)
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.bar(Subjects,Marks)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.bar(Subjects,Marks)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Bar graph")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.bar(Subjects,Marks,color="Pink")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Bar graph")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.bar(Subjects,Marks,color=["grey","orange","yellow","blue","green","black"])
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Bar graph")
plt.show()

# %% [markdown]
# By using barh function

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.barh(Subjects,Marks,color=["grey","orange","yellow","blue","green","black"])
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Bar graph")
plt.show()

# %% [markdown]
# # by using to change the lable of x,y into y,x

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.barh(Subjects,Marks,color=["grey","orange","yellow","blue","green","black"])
plt.ylabel("Subjects")
plt.xlabel("Marks")
plt.title("Bar graph")
plt.show()

# %% [markdown]
# barh = only height not width
#
# bar= only width not height

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.barh(Subjects,Marks,color=["grey","orange","yellow","blue","green","black"],height=1.8)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Bar graph")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.bar(Subjects,Marks,color=["grey","orange","yellow","blue","green","black"],width=0.8)
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.title("Bar graph")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks)
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects)
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,explode=[0.1,0,0,0,0,0])
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,explode=[0,0,0.1,0,0,0])
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,autopct=float)
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,autopct='%f')
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,autopct='%4f')
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,autopct='%8f')
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,autopct='%0.2f')
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(8,3))
plt.pie(Marks,labels=Subjects,autopct='%0.2f',shadow=2)
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(10,8))
plt.pie(Marks,labels=Subjects,autopct='%0.2f',shadow=10)
plt.legend()
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(10,8))
plt.pie(Marks,labels=Subjects,autopct='%1.2f',shadow=10)
plt.legend()
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi']
Marks=[35,55,65,98,78,89]
plt.figure(figsize=(10,8))
plt.pie(Marks,labels=Subjects,autopct='%d',shadow=10)
plt.legend()
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="^",mec="black",mfc="red",markersize=30,linestyle="--")         
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
Subjects=['C','Java','Python','CSS','HTML','Marathi','Hindi','Sanskrit','c++','c#']
Marks=[35,55,65,98,78,89,62,88,99,100]
plt.figure(figsize=(8,3))                                                                            # change the graph size
plt.scatter(Subjects,Marks)
plt.plot(Subjects,Marks,color="green",marker="v",mec="black",mfc="red",markersize=30,linestyle="--")         
plt.title("Scatter plot-Student Report")                                                              # for title name
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
area=[500,600,680,700,750,800]
price=[1200,1500,1800,2000,2500,2700]
plt.figure(figsize=(5,3))
plt.plot(area,price)
plt.title(" line chart: area vs price")
plt.xlabel("area")
plt.ylabel("price")
plt.xlim(400,1000)
plt.show()

# %%
area=[500,600,680,700,750,800]
price=[1200,1500,1800,2000,2500,2700]
plt.figure(figsize=(5,3))
plt.plot(area,price)
plt.title(" line chart: area vs price")
plt.xlabel("area")
plt.ylabel("price")
plt.xlim(400,1000)
plt.ylim(1000,3000)
plt.show()

# %%
area=[500,600,680,700,750,800]
price=[1200,1500,1800,2000,2500,2700]
plt.figure(figsize=(5,3))
plt.plot(area,price)
plt.title(" line chart: area vs price")
plt.xlabel("area")
plt.ylabel("price")
plt.xlim(400,1000)
plt.ylim(1000,3000)
plt.xticks()
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hplap\Downloads\Itvedant\python\Automobile_data.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
df.size
# Out:
# 5330

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
df['Rank']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hplap\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\hplap\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hplap\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rank'
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.head(3)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3                 ?  alfa-romero       gas        std          two  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg
# 0         mpfi  3.47    2.68               9.0        111      5000       21  \
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
#
#   highway-mpg  price
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# ...

# %%
df.tail(3)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors
# 202         -1                95  volvo       gas        std         four  \
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 202      sedan          rwd           front       109.1  ...          173  \
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm
# 202         mpfi  3.58    2.87               8.8        134      5500  \
# 203          idi  3.01     3.4              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 202       18          23  21485
# ...

# %%
df.to_string()
# Out:
# '     symboling normalized-losses           make fuel-type aspiration num-of-doors   body-style drive-wheels engine-location  wheel-base  length  width  height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  price\n0            3                 ?    alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four          130        mpfi  3.47   2.68               9.00        111     5000        21           27  13495\n1            3                 ?    alfa-romero       gas        std          two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc             four          130        mpfi  3.47   2.68               9.00        111     5000        21           27  16500\n2            1                 ?    alfa-romero       gas        std  
# ...

# %%
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors
# 0        False              False  False      False       False         False  \
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...
