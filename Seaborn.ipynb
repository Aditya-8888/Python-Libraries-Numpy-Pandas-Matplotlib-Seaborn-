# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hplap\Downloads\Itvedant\python\Automobile_data.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
df['fuel-type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
pip install matplotlib
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(df['fuel-type'])
plt.show()

# %%
#plt.figure(figsize=(5,3))
sns.countplot(data=df,y=df['fuel-type'])
plt.show()

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3                 ?  alfa-romero       gas        std          two  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
cat_col=['make','fuel-type','aspiration','num-of-doors','body-style','engine-location','drive-wheels']

# %%
cat_col
# Out:
# ['make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'engine-location',
#  'drive-wheels']

# %%
import matplotlib.pyplot as plt

# %%
for col in cat_col:
    sns.countplot(df[col])
    plt.show()

# %%
for col in cat_col:
    plt.figure(figsize=(5,3))
    sns.countplot(df[col],color="g")
    plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(df['body-style'])
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(df['body-style'],color='r')
plt.show()

# %%
plt.figure(figsize=(5,3))
df['body-style'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='body-style'>

# %%
plt.figure(figsize=(5,3))
df['body-style'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='body-style'>

# %%
plt.figure(figsize=(5,3))
df['body-style'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(5,3))
df['body-style'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='body-style'>

# %%
plt.figure(figsize=(5,3))
df['body-style'].value_counts().plot(kind='area')
# Out:
# <Axes: xlabel='body-style'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
num_col=["width","height","engine-size","city-mpg","highway-mpg"]

# %%
num_col
# Out:
# ['width', 'height', 'engine-size', 'city-mpg', 'highway-mpg']

# %%
plt.figure(figsize=(5,3))
sns.distplot(df["width"],color='g')
# Out:
# C:\Users\hplap\AppData\Local\Temp\ipykernel_18740\490273274.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["width"],color='g')
# <Axes: xlabel='width', ylabel='Density'>

# %%
for col in num_col:
    plt.figure(figsize=(5,3))
    sns.distplot(df[col],color='g')
# Out:
# C:\Users\hplap\AppData\Local\Temp\ipykernel_18740\3346606015.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col],color='g')
# C:\Users\hplap\AppData\Local\Temp\ipykernel_18740\3346606015.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(5,3))
sns.histplot(df["width"])
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.kdeplot(df["width"])
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.pairplot(df)
plt.title("pairplot")
plt.show()

# %% [markdown]
# what is the difference between histrogram and bar graph

# %%
plt.figure(figsize=(5,3))
sns.heatmap(df)
plt.show()

# does not run because of ? in the data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 plt.figure(figsize=(5,3))
# ----> 2 sns.heatmap(df)
#       3 plt.show()
#       5 # does not run because of ? in the data
#
# File c:\Users\hplap\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
for col in num_col:
    print(df[col])
# Out:
# 0      64.1
# 1      64.1
# 2      65.5
# 3      66.2
# 4      66.4
#        ...
# 200    68.9
# 201    68.8
# 202    68.9
# 203    68.9
# 204    68.9
# Name: width, Length: 205, dtype: float64
# 0      48.8
# 1      48.8
# 2      52.4
# 3      54.3
# 4      54.3
#        ...
# 200    55.5
# 201    55.5
# 202    55.5
# 203    55.5
# 204    55.5
# Name: height, Length: 205, dtype: float64
# 0      130
# 1      130
# 2      152
# 3      109
# 4      136
#       ...
# 200    141
# 201    141
# 202    173
# 203    145
# 204    141
# Name: engine-size, Length: 205, dtype: int64
# 0      21
# 1      21
# 2      19
# 3      24
# 4      18
#        ..
# 200    23
# 201    19
# 202    18
# 203    26
# 204    19
# Name: city-mpg, Length: 205, dtype: int64
# 0      27
# 1      27
# 2      26
# 3      30
# 4      22
#        ..
# 200    28
# 201    25
# 202    23
# 203    27
# 204    25
# Name: highway-mpg, Length: 205, dtype: int64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
num_col
# Out:
# ['width', 'height', 'engine-size', 'city-mpg', 'highway-mpg']

# %%
plt.figure(figsize=(5,3))
sns.boxplot(df['width'])
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(df['width'],color='pink')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,x='width')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,x='width',color='r')
plt.show()

# %%
for col in num_col:
    sns.boxplot(df[col],color="darkblue")
    plt.show()

# %%
df['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '32250', '35550', '36000',
#        '5195', '6095', '6795', '6695', '7395', '10945', '11845', '13645',
#        '15645', '8495', '10595', '10245', '10795', '11245', '18280',
#        '18344', '25552', '28248', '28176', '31600', '34184', '35056',
#        '40960', '45400', '16503', '5389', '6189', '6669', '7689', '9959',
#        '8499', '12629', '14869', '14489', '6989', '8189', '9279', '5499',
#        '7099', '6649', '6849', '7349', '7299', '7799', '7499', '7999',
#        '8249', '8949', '9549', '13499', '14399', '17199', '19699',
# ...

# %%
import numpy as np

# %%
df['price'].replace('?',np.NAN)
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
df['price'].replace('?',np.NAN,inplace=True)

# %%
df.replace('?',np.NAN,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.drop('normalized-losses',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 df.drop('normalized-losses',axis=1,inplace=True)
#
# File c:\Users\hplap\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['price']=df['price'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          193 non-null    int64
#  1   make               193 non-null    object
#  2   fuel-type          193 non-null    object
#  3   aspiration         193 non-null    object
#  4   num-of-doors       193 non-null    object
#  5   body-style         193 non-null    object
#  6   drive-wheels       193 non-null    object
#  7   engine-location    193 non-null    object
#  8   wheel-base         193 non-null    float64
#  9   length             193 non-null    float64
#  10  width              193 non-null    float64
#  11  height             193 non-null    float64
#  12  curb-weight        193 non-null    int64
#  13  engine-type        193 non-null    object
#  14  num-of-cylinders   193 non-null    object
#  15  engine-size        193 non-null    int64
# ...

# %%
plt.figure(figsize=(5,3))
sns.boxplot(df['price'],color='red')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,color='r',x='price')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,color='pink',x='price',hue='fuel-type')
plt.show()
# Out:
# C:\Users\hplap\AppData\Local\Temp\ipykernel_11436\122976195.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.boxplot(data=df,color='pink',x='price',hue='fuel-type')

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,color='pink',x='price',hue='make')
plt.show()
# Out:
# C:\Users\hplap\AppData\Local\Temp\ipykernel_11436\2553920955.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.boxplot(data=df,color='pink',x='price',hue='make')

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,x='price',hue='make')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='price',y='make')
plt.show()

# %%
import numpy as np

# %%
x=np.random.randint(10,100,100)
plt.plot(x,np.sqrt(x))
plt.show()

# %%
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')
plt.show()

# %%
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')
plt.plot(x,np.log(x),label='log graph')
plt.plot(x,np.sin(x),label='sin graph')
plt.plot(x,np.cos(x),label='cos graph')
plt.legend()
plt.show()

# %%
x=np.random.randint(10,100)
x
# Out:
# 70

# %%
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')
plt.show()
plt.plot(x,np.log(x),label='log graph')
plt.show()
plt.plot(x,np.sin(x),label='sin graph')
plt.show()
plt.plot(x,np.cos(x),label='cos graph')
plt.show()
#plt.legend()
plt.show()

# %%
plt.subplot(2,2,1)
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')

plt.subplot(2,2,2)
plt.plot(x,np.log(x),label='log graph')

plt.subplot(2,2,3)
plt.plot(x,np.sin(x),label='sin graph')

plt.subplot(2,2,4)
plt.plot(x,np.cos(x),label='cos graph')

plt.show()

# %%
plt.subplot(2,2,1)
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')
plt.title('sqrt')

plt.subplot(2,2,2)
plt.plot(x,np.log(x),label='log graph')
plt.title('log')

plt.subplot(2,2,3)
plt.plot(x,np.sin(x),label='sin graph')
plt.title('sin')

plt.subplot(2,2,4)
plt.plot(x,np.cos(x),label='cos graph')
plt.title('cos')

plt.show()

# %%
plt.subplot(3,3,1)
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')
plt.title('sqrt')

plt.subplot(3,3,2)
plt.plot(x,np.log(x),label='log graph')
plt.title('log')

plt.subplot(3,3,3)
plt.plot(x,np.sin(x),label='sin graph')
plt.title('sin')

plt.subplot(3,3,4)
plt.plot(x,np.cos(x),label='cos graph')
plt.title('cos')

plt.show()

# %%
plt.subplot(3,3,1)
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph')
plt.title('sqrt')

plt.subplot(3,3,3)
plt.plot(x,np.log(x),label='log graph')
plt.title('log')

plt.subplot(3,3,7)
plt.plot(x,np.sin(x),label='sin graph')
plt.title('sin')

plt.subplot(3,3,9)
plt.plot(x,np.cos(x),label='cos graph')
plt.title('cos')

plt.show()

# %%
plt.subplot(3,3,1)
x=np.arange(10,100)
plt.plot(x,np.sqrt(x),label='sqrt graph',color='black')
plt.title('sqrt')

plt.subplot(3,3,3)
plt.plot(x,np.log(x),label='log graph',color='blue')
plt.title('log')

plt.subplot(3,3,7)
plt.plot(x,np.sin(x),label='sin graph',color='red')
plt.title('sin')

plt.subplot(3,3,9)
plt.plot(x,np.cos(x),label='cos graph',color='green')
plt.title('cos')

plt.show()

# %%
data_set=np.random.rand(10,10)
data_set
# Out:
# array([[0.16250151, 0.36305938, 0.97750462, 0.36998739, 0.67848539,
#         0.09573495, 0.89793902, 0.85736094, 0.83223039, 0.51669331],
#        [0.02105134, 0.38951605, 0.03940611, 0.28439232, 0.48743512,
#         0.56007393, 0.84144871, 0.46064258, 0.16461122, 0.2458004 ],
#        [0.72606892, 0.00539893, 0.09857167, 0.58825973, 0.24190871,
#         0.16539534, 0.89666383, 0.112645  , 0.47305384, 0.53095358],
#        [0.98133798, 0.13225304, 0.1776254 , 0.7163412 , 0.94888705,
#         0.64386878, 0.60208742, 0.3901581 , 0.54537102, 0.04875542],
#        [0.16069411, 0.51131029, 0.53391993, 0.60630493, 0.24383577,
#         0.09102704, 0.02200774, 0.45015724, 0.81699566, 0.9921722 ],
#        [0.01537789, 0.85443318, 0.72104402, 0.59282497, 0.91366614,
#         0.0827894 , 0.58808449, 0.19777609, 0.12546654, 0.72371065],
#        [0.53808251, 0.07545943, 0.97890758, 0.11876391, 0.51324749,
#         0.67549909, 0.34149632, 0.88989971, 0.58443727, 0.74784406],
# ...

# %%
sns.heatmap(data_set)
plt.show()

# %%
sns.heatmap(data_set,cmap='coolwarm')
plt.show()

# %%
sns.heatmap(data_set,cmap='summer')
plt.show()

# %%
sns.heatmap(data_set,cmap='winter')
plt.show()

# %%
sns.heatmap(data_set,cmap='autumn')
plt.show()

# %%
sns.heatmap(data_set,cmap='cool')
plt.show()
